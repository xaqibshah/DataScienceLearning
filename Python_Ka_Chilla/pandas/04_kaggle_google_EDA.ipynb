# %% [markdown]
# # Goodle paly store EDA
# ### Complete Expolratory Data Analysis

# %% [markdown]
# #### 1. Import libraries

# %%
#import libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Load datasets

# %%
# data import   
df = pd.read_csv('./data/googleplaystore.csv')

# %% [markdown]
# - Important Things to know

# %%
#set option to be maximum for rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# hide all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_mb', 'popularity'],
#       dtype='object')

# %%
print(f"The numbers of columns are follows: {df.columns}")
# Out:
# The numbers of columns are follows: Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_mb', 'popularity'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 15)

# %%
print(f'The number of Rows are {df.shape[0]} and columns are {df.shape[1]}')
# Out:
# The number of Rows are 10841 and columns are 15

# %%
# profile = yd.ProfileReport(df)

# profile.to_file(output_file="./output/google.html")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.sample(10)
# Out:
#                                                      App             Category  \
# 10558      Austria Wien FK - Fussball - Inoffizielle App               SPORTS
# 4507    Q downloader : download your social media videos               FAMILY
# 3293                        CM Flashlight (Compass, SOS)                TOOLS
# 1663                                          Helix Jump                 GAME
# 310    Comic Es - Shojo manga / love comics free of c...               COMICS
# 8006                         Morse Trainer for Ham Radio        COMMUNICATION
# 1596                  PASS by KT (formerly KT certified)            LIFESTYLE
# 8966                                            DV Youth            LIFESTYLE
# 3831                                         Air Traffic  MAPS_AND_NAVIGATION
# 3671                             Video Player All Format        VIDEO_PLAYERS
#
#        Rating  Reviews                Size      Installs  Type   Price  \
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# # write the all the numeric columns and make them numerics
#
#
# 1. size
# 2. install
# 3. price

# %%
#write the all the numeric columns and make them numerics

# %%
df.nunique().sum()
df['Size'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         19M
# 1         14M
# 2        8.7M
# 3         25M
# 4        2.8M
#          ...
# 10836     53M
# 10837    3.6M
# 10838    9.5M
# 10839    2.2M
# 10840     19M
# Name: Size, Length: 10841, dtype: object>

# %% [markdown]
# # check how many mbs in kb  are there ? how to calculate
#
# 1. convert MB to KB
# 2. Then Remove M from all number
# 3. Handle `varies with device`

# %%
df['Size'].value_counts
# df.head()
# Out:
# <bound method IndexOpsMixin.value_counts of 0         19M
# 1         14M
# 2        8.7M
# 3         25M
# 4        2.8M
#          ...
# 10836     53M
# 10837    3.6M
# 10838    9.5M
# 10839    2.2M
# 10840     19M
# Name: Size, Length: 10841, dtype: object>

# %%
#Remove + From Installs columns
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace('+','') if '+' in str(x) else str(x))
#Remove , From Installs columns
df['Installs'] = df['Installs'].apply(lambda x: str(x).replace(',','') if ',' in str(x) else str(x))
# convert installs to int data type
df['Installs'] = df['Installs'].apply(lambda x: int(x))
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
# 3   215644   25M  50000000  Free     0           Teen
# 4      967  2.8M    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# 11.000000    198
# 12.000000    196
# 14.000000    194
# 13.000000    191
# 15.000000    184
#             ...
# 0.419922       1
# 0.418945       1
# 0.195312       1
# 0.449219       1
# 0.604492       1
# Name: count, Length: 459, dtype: int64

# %%
def convert_size(size):
    if 'm' in size:
        return float(size[:-1])  # Remove 'm' and convert to float
    elif 'k' in size:
        return float(size[:-1]) / 1024  # Remove 'k', convert to float, and divide by 1024
    elif size == 'Varies with device':
        return np.nan
    else:
        return float(size)  # No conversion needed

# %%
# create a new columns by size_mb and apply convert_size function to it

df['Size_mb'] = df['Size'].apply(convert_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\xaqibshah\Desktop\DataScienceLearning\Python_Ka_Chilla\pandas\04_kaggle_google_EDA.ipynb Cell 17 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/xaqibshah/Desktop/DataScienceLearning/Python_Ka_Chilla/pandas/04_kaggle_google_EDA.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # create a new columns by size_mb and apply convert_size function to it
# ----> <a href='vscode-notebook-cell:/c%3A/Users/xaqibshah/Desktop/DataScienceLearning/Python_Ka_Chilla/pandas/04_kaggle_google_EDA.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> df['Size_mb'] = df['Size'].apply(convert_size)
#
# File c:\Users\xaqibshah\.conda\envs\python_eda\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
# ...

# %%
df['Size'].value_counts()
# Out:
# Size
# 11.000000    198
# 12.000000    196
# 14.000000    194
# 13.000000    191
# 15.000000    184
#             ...
# 0.419922       1
# 0.418945       1
# 0.195312       1
# 0.449219       1
# 0.604492       1
# Name: count, Length: 459, dtype: int64

# %%
# remove $ sign from price and convert into Float
df['Price'] = df['Price'].apply(lambda x: str(x).replace('$','') if '$' in str(x) else str(x))
#convert df['Price'] into float data type
df['Price'] = df['Price'].apply(lambda x: float(x))
# df['Price'].value_counts()
# Out:
# Price
# 0.00     10041
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 19.90        1
# 1.75         1
# 14.00        1
# 4.85         1
# 1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df.select_dtypes(include='number').head()
# Out:
#    Rating  Reviews  Size  Installs  Price
# 0     4.1      159  19.0     10000    0.0
# 1     3.9      967  14.0    500000    0.0
# 2     4.7    87510   8.7   5000000    0.0
# 3     4.5   215644  25.0  50000000    0.0
# 4     4.3      967   2.8    100000    0.0

# %%
# Assuming df is your DataFrame and 'installs' is your column of interest
bins = [0, 50000, 100000, float('inf')]  # Define your bins
labels = ['Less Famous App', 'Famous App', 'Most Famous App']  # Define your labels

df['popularity'] = pd.cut(df['Installs'], bins=bins, labels=labels)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...
