# %% [markdown]
# # 16- splited a string into multiple columns

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame({"name": ['ahmed', 'saqib', 'walid','anas','waleed'],
'location':['LA, USA', 'Karachi, Pakistan', 'washanton,USA','lahore,USA', 'paris,London']})
df
# Out:
#      name           location
# 0   ahmed            LA, USA
# 1   saqib  Karachi, Pakistan
# 2   walid      washanton,USA
# 3    anas         lahore,USA
# 4  waleed       paris,London

# %%
df.location.str.split(",").head()
# Out:
# 0              [LA,  USA]
# 1    [Karachi,  Pakistan]
# 2        [washanton, USA]
# 3           [lahore, USA]
# 4         [paris, London]
# Name: location, dtype: object

# %%
# spliting column into two columns
df.location.str.split(",", expand=True)
# Out:
#            0          1
# 0         LA        USA
# 1    Karachi   Pakistan
# 2  washanton        USA
# 3     lahore        USA
# 4      paris     London

# %%
# adding splited columns in diffrent columns
df[["city", "country"]] = df.location.str.split(",", expand=True)
df
# Out:
#      name           location       city    country
# 0   ahmed            LA, USA         LA        USA
# 1   saqib  Karachi, Pakistan    Karachi   Pakistan
# 2   walid      washanton,USA  washanton        USA
# 3    anas         lahore,USA     lahore        USA
# 4  waleed       paris,London      paris     London

# %%
df = df[['name', 'city', 'country']]
df
# Out:
#      name       city    country
# 0   ahmed         LA        USA
# 1   saqib    Karachi   Pakistan
# 2   walid  washanton        USA
# 3    anas     lahore        USA
# 4  waleed      paris     London

# %% [markdown]
# # 17- aggregate by multiple groups/function

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import datasets
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('who').count()
df.groupby('sex').count()
# df.head()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
# df.groupby('who').sum() not support sum function
len(df.groupby('who'))
# Out:
# 3

# %%
df.groupby(["sex", "adult_male", "pclass"]).count()
df.groupby(['sex', 'who', "embarked"]).count()
# Out:
#                        survived  pclass  age  sibsp  parch  fare  class  \
# sex    who   embarked
# female child C               13      13   13     13     13    13     13
#              Q                1       1    1      1      1     1      1
#              S               29      29   29     29     29    29     29
#        woman C               60      60   48     60     60    60     60
#              Q               35      35   11     35     35    35     35
#              S              174     174  157    174    174   174    174
# male   child C                5       5    5      5      5     5      5
#              Q                4       4    4      4      4     4      4
#              S               31      31   31     31     31    31     31
#        man   C               90      90   64     90     90    90     90
#              Q               37      37   12     37     37    37     37
#              S              410     410  337    410    410   410    410
#
#                        adult_male  deck  embark_town  alive  alone
# sex    who   embarked
# female child C                 13     0           13     13     13
#              Q                  1     0            1      1      1
#              S                 29     6           29     29     29
#        woman C                 60    37           60     60     60
#              Q                 35     2           35     35     35
#              S                174    50          174    174    174
# male   child C                  5     0            5      5      5
#              Q                  4     0            4      4      4
#              S                 31     7           31     31     31
#        man   C                 90    32           90     90     90
#              Q                 37     2           37     37     37
#              S                410    65          410    410    410

# %% [markdown]
# # 18 - select specific rows and columns

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sex', 'class', 'deck']]
# Out:
#         sex   class deck
# 0      male   Third  NaN
# 1    female   First    C
# 2    female   Third  NaN
# 3    female   First    C
# 4      male   Third  NaN
# ..      ...     ...  ...
# 886    male  Second  NaN
# 887  female   First    B
# 888  female   Third  NaN
# 889    male   First    C
# 890    male   Third  NaN
#
# [891 rows x 3 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc[["min", '25%' , 'max']]
# Out:
#      survived  pclass     age  sibsp  parch      fare
# min       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%       0.0     2.0  20.125    0.0    0.0    7.9104
# max       1.0     3.0  80.000    8.0    6.0  512.3292

# %%
df.describe().loc["min":'max']
df.describe().loc['min':'max', 'survived':'age']
# Out:
#      survived  pclass     age
# min       0.0     1.0   0.420
# 25%       0.0     2.0  20.125
# 50%       0.0     3.0  28.000
# 75%       1.0     3.0  38.000
# max       1.0     3.0  80.000

# %% [markdown]
# # 19- Reshape multiindex series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.mean()
# Out:
# 0.3838383838383838

# %%
df.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','class']).survived.mean()
# Out:
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex', 'class']).survived.mean().unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 20- Continous to catogirical data conversion

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
pd.cut(df.age, bins = [0,18,25,99], labels=['child', 'young_adults', 'adult']).head()
df["new_age"] = pd.cut(df.age, bins = [1,18,25,99], labels=['child', 'young_adult', 'adult'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %% [markdown]
# # 21- convert one set of data into another

# %%
df.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
# convert to sex into numbe
df.sex.map({'male':0, 'female':1})
# feature engineering 
df['sex_num'] = df.sex.map({"male" : 0, "female":1})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0

# %%
df.embarked.count()
df.embarked.unique()
# df.embarked.factorize()[0]
df['embarked_num'] = df.embarked.factorize()[0]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num  \
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0
#
#    embarked_num
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %% [markdown]
# # 22- transpse a wide dataframe

# %%
import numpy as np
import pandas as pd

# %%
#create a new df
df = pd.DataFrame(np.random.rand(200,25), columns=list('abcdefghijklmnopqrstuvwxy'))
df.head()
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.348087  0.840197  0.664583  0.398913  0.112152  0.087294  0.176501
# 1  0.718664  0.299859  0.535967  0.368129  0.118554  0.294848  0.182795
# 2  0.541893  0.188256  0.734147  0.918205  0.368319  0.428132  0.391741
# 3  0.474057  0.642528  0.573256  0.647339  0.601019  0.050165  0.636247
# 4  0.129095  0.186315  0.796263  0.913376  0.187665  0.912624  0.656942
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.133099  0.078906  0.364201  ...  0.126834  0.444605  0.194563  0.145134
# 1  0.200382  0.233498  0.439658  ...  0.328259  0.590176  0.959675  0.396214
# 2  0.542509  0.017893  0.794967  ...  0.587754  0.039114  0.181850  0.722389
# 3  0.528575  0.934331  0.816679  ...  0.459577  0.075524  0.915135  0.697160
# 4  0.185427  0.665176  0.778045  ...  0.512905  0.227504  0.736418  0.700975
#
#           t         u         v         w         x         y
# 0  0.148839  0.307807  0.662988  0.132478  0.912319  0.892150
# 1  0.995804  0.052333  0.281686  0.599327  0.127184  0.782100
# 2  0.140343  0.245416  0.434149  0.520618  0.146676  0.523128
# 3  0.103091  0.622484  0.170399  0.872842  0.829882  0.440895
# 4  0.820577  0.000548  0.849799  0.338946  0.645538  0.597281
#
# [5 rows x 25 columns]

# %%
#transpose a column
df.head().T
# Out:
#           0         1         2         3         4
# a  0.348087  0.718664  0.541893  0.474057  0.129095
# b  0.840197  0.299859  0.188256  0.642528  0.186315
# c  0.664583  0.535967  0.734147  0.573256  0.796263
# d  0.398913  0.368129  0.918205  0.647339  0.913376
# e  0.112152  0.118554  0.368319  0.601019  0.187665
# f  0.087294  0.294848  0.428132  0.050165  0.912624
# g  0.176501  0.182795  0.391741  0.636247  0.656942
# h  0.133099  0.200382  0.542509  0.528575  0.185427
# i  0.078906  0.233498  0.017893  0.934331  0.665176
# j  0.364201  0.439658  0.794967  0.816679  0.778045
