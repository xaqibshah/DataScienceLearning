# %% [markdown]
#
#  gfda1  qa3# 16- splited a string into multiple columns

# %%
df = pd.DataFrame({"name": ['ahmed', 'saqib', 'walid','anas','waleed'],
'location':['LA, USA', 'Karachi, Pakistan', 'washanton,USA','lahore,USA', 'paris,London']})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\xaqibshah\Desktop\DataScienceLearning\Python_Ka_Chilla\pandas\02b_panda_tip_and_tricks.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/xaqibshah/Desktop/DataScienceLearning/Python_Ka_Chilla/pandas/02b_panda_tip_and_tricks.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame({"name": ['ahmed', 'saqib', 'walid','anas','waleed'],
#       <a href='vscode-notebook-cell:/c%3A/Users/xaqibshah/Desktop/DataScienceLearning/Python_Ka_Chilla/pandas/02b_panda_tip_and_tricks.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> 'location':['LA, USA', 'Karachi, Pakistan', 'washanton,USA','lahore,USA', 'paris,London']})
#       <a href='vscode-notebook-cell:/c%3A/Users/xaqibshah/Desktop/DataScienceLearning/Python_Ka_Chilla/pandas/02b_panda_tip_and_tricks.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> df
#
# NameError: name 'pd' is not defined

# %%
df.location.str.split(",").head()
# Out:
# 0              [LA,  USA]
# 1    [Karachi,  Pakistan]
# 2        [washanton, USA]
# 3           [lahore, USA]
# 4         [paris, London]
# Name: location, dtype: object

# %%
# spliting column into two columns
df.location.str.split(",", expand=True)
# Out:
#            0          1
# 0         LA        USA
# 1    Karachi   Pakistan
# 2  washanton        USA
# 3     lahore        USA
# 4      paris     London

# %%
# adding splited columns in diffrent columns
df[["city", "country"]] = df.location.str.split(",", expand=True)
df
# Out:
#      name           location       city    country
# 0   ahmed            LA, USA         LA        USA
# 1   saqib  Karachi, Pakistan    Karachi   Pakistan
# 2   walid      washanton,USA  washanton        USA
# 3    anas         lahore,USA     lahore        USA
# 4  waleed       paris,London      paris     London

# %%
df = df[['name', 'city', 'country']]
df
# Out:
#      name       city    country
# 0   ahmed         LA        USA
# 1   saqib    Karachi   Pakistan
# 2   walid  washanton        USA
# 3    anas     lahore        USA
# 4  waleed      paris     London

# %% [markdown]
# # 17- aggregate by multiple groups/function

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import datasets
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('who').count()
df.groupby('sex').count()
# df.head()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
# df.groupby('who').sum() not support sum function
len(df.groupby('who'))
# Out:
# 3

# %%
df.groupby(["sex", "adult_male", "pclass"]).count()
df.groupby(['sex', 'who', "embarked"]).count()
# Out:
#                        survived  pclass  age  sibsp  parch  fare  class  \
# sex    who   embarked
# female child C               13      13   13     13     13    13     13
#              Q                1       1    1      1      1     1      1
#              S               29      29   29     29     29    29     29
#        woman C               60      60   48     60     60    60     60
#              Q               35      35   11     35     35    35     35
#              S              174     174  157    174    174   174    174
# male   child C                5       5    5      5      5     5      5
#              Q                4       4    4      4      4     4      4
#              S               31      31   31     31     31    31     31
#        man   C               90      90   64     90     90    90     90
#              Q               37      37   12     37     37    37     37
#              S              410     410  337    410    410   410    410
#
# ...

# %% [markdown]
# # 18 - select specific rows and columns

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sex', 'class', 'deck']]
# Out:
#         sex   class deck
# 0      male   Third  NaN
# 1    female   First    C
# 2    female   Third  NaN
# 3    female   First    C
# 4      male   Third  NaN
# ..      ...     ...  ...
# 886    male  Second  NaN
# 887  female   First    B
# 888  female   Third  NaN
# 889    male   First    C
# 890    male   Third  NaN
#
# [891 rows x 3 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc[["min", '25%' , 'max']]
# Out:
#      survived  pclass     age  sibsp  parch      fare
# min       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%       0.0     2.0  20.125    0.0    0.0    7.9104
# max       1.0     3.0  80.000    8.0    6.0  512.3292

# %%
df.describe().loc["min":'max']
df.describe().loc['min':'max', 'survived':'age']
# Out:
#      survived  pclass     age
# min       0.0     1.0   0.420
# 25%       0.0     2.0  20.125
# 50%       0.0     3.0  28.000
# 75%       1.0     3.0  38.000
# max       1.0     3.0  80.000

# %% [markdown]
# # 19- Reshape multiindex series

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.survived.mean()
# Out:
# 0.3838383838383838

# %%
df.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','class']).survived.mean()
# Out:
# C:\Users\xaqibshah\AppData\Local\Temp\ipykernel_11192\1967038050.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','class']).survived.mean()
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex', 'class']).survived.mean().unstack()
# Out:
# C:\Users\xaqibshah\AppData\Local\Temp\ipykernel_11192\1574924337.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex', 'class']).survived.mean().unstack()
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # 20- Continous to catogirical data conversion

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
pd.cut(df.age, bins = [0,18,25,99], labels=['child', 'young_adults', 'adult']).head()
df["new_age"] = pd.cut(df.age, bins = [1,18,25,99], labels=['child', 'young_adult', 'adult'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %% [markdown]
# # 21- convert one set of data into another

# %%
df.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
# convert to sex into numbe
df.sex.map({'male':0, 'female':1})
# feature engineering 
df['sex_num'] = df.sex.map({"male" : 0, "female":1})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0

# %%
df.embarked.count()
df.embarked.unique()
# df.embarked.factorize()[0]
df['embarked_num'] = df.embarked.factorize()[0]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num  \
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0
#
#    embarked_num
# 0             0
# 1             1
# 2             0
# ...

# %% [markdown]
# # 22- transpse a wide dataframe

# %%
import numpy as np
import pandas as pd

# %%
#create a new df
df = pd.DataFrame(np.random.rand(200,25), columns=list('abcdefghijklmnopqrstuvwxy'))
df.head()
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.811288  0.235127  0.537908  0.485849  0.093131  0.513846  0.934397
# 1  0.583239  0.957732  0.263196  0.453155  0.137473  0.527725  0.121358
# 2  0.671521  0.389136  0.216407  0.501469  0.576926  0.467907  0.722688
# 3  0.985075  0.972540  0.877115  0.322996  0.933923  0.190402  0.257988
# 4  0.833159  0.072994  0.836262  0.694042  0.339171  0.581742  0.421441
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.919023  0.878676  0.390996  ...  0.427356  0.885960  0.889902  0.948885
# 1  0.461773  0.042901  0.707762  ...  0.536432  0.098736  0.163081  0.720289
# 2  0.773425  0.975290  0.493827  ...  0.971242  0.422479  0.148681  0.820198
# 3  0.328263  0.463566  0.135967  ...  0.512484  0.181012  0.072912  0.781295
# 4  0.421678  0.393891  0.648589  ...  0.033411  0.731986  0.762834  0.536365
#
#           t         u         v         w         x         y
# ...

# %%
#transpose a column
df.head().T
# Out:
#           0         1         2         3         4
# a  0.811288  0.583239  0.671521  0.985075  0.833159
# b  0.235127  0.957732  0.389136  0.972540  0.072994
# c  0.537908  0.263196  0.216407  0.877115  0.836262
# d  0.485849  0.453155  0.501469  0.322996  0.694042
# e  0.093131  0.137473  0.576926  0.933923  0.339171
# f  0.513846  0.527725  0.467907  0.190402  0.581742
# g  0.934397  0.121358  0.722688  0.257988  0.421441
# h  0.919023  0.461773  0.773425  0.328263  0.421678
# i  0.878676  0.042901  0.975290  0.463566  0.393891
# j  0.390996  0.707762  0.493827  0.135967  0.648589
# k  0.317525  0.959368  0.182310  0.423552  0.955026
# l  0.830294  0.162839  0.278070  0.764668  0.027214
# m  0.389199  0.773439  0.515950  0.176947  0.157152
# n  0.881831  0.708313  0.887872  0.651847  0.017005
# o  0.245145  0.401308  0.737952  0.104223  0.640335
# p  0.427356  0.536432  0.971242  0.512484  0.033411
# q  0.885960  0.098736  0.422479  0.181012  0.731986
# ...

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# a  200.0  0.465367  0.291973  0.001689  0.206239  0.420618  0.735064  0.991194
# b  200.0  0.510817  0.283058  0.003235  0.267246  0.492629  0.756657  0.999624
# c  200.0  0.520228  0.289487  0.016179  0.278308  0.534917  0.785099  0.985322
# d  200.0  0.505108  0.279842  0.002040  0.269279  0.499016  0.728937  0.985715
# e  200.0  0.498160  0.278339  0.000471  0.271370  0.478932  0.723122  0.995685
# f  200.0  0.508795  0.288598  0.003813  0.265584  0.511406  0.757824  0.996154
# g  200.0  0.505379  0.276330  0.004774  0.265421  0.528872  0.731814  0.991218
# h  200.0  0.511293  0.291582  0.000875  0.272437  0.521169  0.749580  0.999714
# i  200.0  0.517641  0.290494  0.001441  0.264434  0.523406  0.759361  0.998604
# j  200.0  0.510937  0.289479  0.001052  0.281557  0.491959  0.764901  0.998488
# k  200.0  0.486813  0.281251  0.000214  0.274780  0.474099  0.713106  0.990771
# ...

# %% [markdown]
# # 23- Reshaping a dataframe

# %%
fasla = pd.DataFrame([['12345', 100,200,300], ['34567', 400,500,600],['67890',700,800,900]] , columns=['zip', 'factory','warehouse','retail'])
fasla.head()
fasla.head().T
# Out:
#                0      1      2
# zip        12345  34567  67890
# factory      100    400    700
# warehouse    200    500    800
# retail       300    600    900

# %%
sns.barplot(x="zip", y=['factory', 'warehouse', 'retail'], data=fasla)
# Out:
# <Axes: xlabel='zip'>

# %%
fasla2 =pd.DataFrame([[1,'1234', 'factory'], [2, '34567', 'warehouse']],
columns=['user_id', 'zip', 'location_type'])
fasla2
# Out:
#    user_id    zip location_type
# 0        1   1234       factory
# 1        2  34567     warehouse

# %%
fasla_long = fasla.melt(id_vars='zip', var_name='location_type', value_name='distance')

# %%
fasla_long
# Out:
#      zip location_type  distance
# 0  12345       factory       100
# 1  34567       factory       400
# 2  67890       factory       700
# 3  12345     warehouse       200
# 4  34567     warehouse       500
# 5  67890     warehouse       800
# 6  12345        retail       300
# 7  34567        retail       600
# 8  67890        retail       900

# %%
sns.barplot(x="zip", y="distance", hue='location_type', data=fasla_long)
# Out:
# <Axes: xlabel='zip', ylabel='distance'>
